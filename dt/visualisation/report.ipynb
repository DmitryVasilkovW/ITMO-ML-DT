# %%
from dt.hyperparameter.hyperparameter_selection import HyperparameterSelection
from dt.plot.plots import show_decision_tree_classifier_lib_impl
from dt.plot.plots import show_random_forest_classifier_lib_impl
from dt.plot.plots import show_gradient_boost_classifier_lib_impl
from dt.plot.plots import show_my_decision_tree_impl
from dt.plot.plots import show_my_random_forest_impl
from dt.hyperparameter.hyperparameters_render import show_best_params

# %% [markdown]
# ### Hyperparameters

# %%
show_best_params()
# Out:
# The best min samples split is 10
# The best min samples leaf is 2
# The best max depth is None
# The best score is 0.8802083333333334

# %% [markdown]
# ### Plot of decision tree using lib implementation

# %%
min_samples_split = HyperparameterSelection.get_best_min_samples_split()
min_samples_leaf = HyperparameterSelection.get_best_min_samples_leaf()

# %%
show_decision_tree_classifier_lib_impl(min_samples_split, min_samples_leaf)

# %% [markdown]
# ### Plot of random forest using lib implementation

# %%
show_random_forest_classifier_lib_impl(min_samples_split, min_samples_leaf)

# %% [markdown]
# ### Plot of boosting using lib implementation

# %%
show_gradient_boost_classifier_lib_impl(min_samples_split, min_samples_leaf)

# %% [markdown]
# ### Plot of decision tree using my implementation

# %%
show_my_decision_tree_impl(min_samples_split, min_samples_leaf)

# %% [markdown]
# ### Plot of random forest using my implementation

# %%
show_my_random_forest_impl(min_samples_split, min_samples_leaf)
